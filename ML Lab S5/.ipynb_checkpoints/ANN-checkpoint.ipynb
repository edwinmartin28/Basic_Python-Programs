# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from keras.models import Sequential 
from keras.layers import Dense 
from keras.layers import LeakyReLU,PReLU,ELU 
from keras.layers import Dropout
dataset= pd.read_csv('Churn_Modelling.csv')
dataset.head()
X= dataset.iloc[:,3:-1]
y=dataset.iloc[:,-1]
X.head()
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender= pd.get_dummies(X['Gender'],drop_first=True)
X=pd.concat([X,geography,gender],axis=1)

X.drop(['Geography','Gender'],axis=1,inplace=True)
X.head()
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
classifier= Sequential()
classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu',input_dim=11))

classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu'))

classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))
classifier.summary()

classifier.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

model_history=classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs=50)

y_pred= classifier.predict(X_test)
y_pred= (y_pred>0.5)
#y_pred
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

cm= confusion_matrix(y_test,y_pred)
print(cm)
accuracy=accuracy_score(y_test,y_pred)
print('The accuracy of the model is',accuracy)
cl_report = classification_report(y_test,y_pred)
print(cl_report)
print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 6)                 72
#
#  dense_13 (Dense)            (None, 6)                 42
#
#  dense_14 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 536/536 [==============================] - 2s 2ms/step - loss: 0.6175 - accuracy: 0.6876 - val_loss: 0.4955 - val_accuracy: 0.7925
# Epoch 2/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4750 - accuracy: 0.7959 - val_loss: 0.4633 - val_accuracy: 0.7959
# Epoch 3/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4542 - accuracy: 0.7975 - val_loss: 0.4509 - val_accuracy: 0.7963
# Epoch 4/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4446 - accuracy: 0.7983 - val_loss: 0.4445 - val_accuracy: 0.7955
# Epoch 5/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4381 - accuracy: 0.7988 - val_loss: 0.4413 - val_accuracy: 0.7978
# Epoch 6/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4320 - accuracy: 0.8018 - val_loss: 0.4392 - val_accuracy: 0.7997
# Epoch 7/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4281 - accuracy: 0.8013 - val_loss: 0.4387 - val_accuracy: 0.8016
# Epoch 8/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4255 - accuracy: 0.8031 - val_loss: 0.4377 - val_accuracy: 0.8039
# Epoch 9/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4231 - accuracy: 0.8067 - val_loss: 0.4369 - val_accuracy: 0.8076
# Epoch 10/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4209 - accuracy: 0.8110 - val_loss: 0.4360 - val_accuracy: 0.8137
# Epoch 11/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4183 - accuracy: 0.8141 - val_loss: 0.4345 - val_accuracy: 0.8122
# Epoch 12/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4154 - accuracy: 0.8182 - val_loss: 0.4327 - val_accuracy: 0.8141
# Epoch 13/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4125 - accuracy: 0.8231 - val_loss: 0.4314 - val_accuracy: 0.8164
# Epoch 14/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4088 - accuracy: 0.8266 - val_loss: 0.4305 - val_accuracy: 0.8148
# Epoch 15/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4054 - accuracy: 0.8270 - val_loss: 0.4290 - val_accuracy: 0.8198
# Epoch 16/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4010 - accuracy: 0.8293 - val_loss: 0.4262 - val_accuracy: 0.8175
# Epoch 17/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3952 - accuracy: 0.8352 - val_loss: 0.4208 - val_accuracy: 0.8270
# Epoch 18/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3875 - accuracy: 0.8397 - val_loss: 0.4141 - val_accuracy: 0.8247
# Epoch 19/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3776 - accuracy: 0.8434 - val_loss: 0.4103 - val_accuracy: 0.8243
# Epoch 20/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3676 - accuracy: 0.8474 - val_loss: 0.3966 - val_accuracy: 0.8379
# Epoch 21/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3591 - accuracy: 0.8522 - val_loss: 0.3894 - val_accuracy: 0.8372
# Epoch 22/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3521 - accuracy: 0.8576 - val_loss: 0.3856 - val_accuracy: 0.8379
# Epoch 23/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3483 - accuracy: 0.8569 - val_loss: 0.3789 - val_accuracy: 0.8432
# Epoch 24/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3447 - accuracy: 0.8567 - val_loss: 0.3762 - val_accuracy: 0.8432
# Epoch 25/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3421 - accuracy: 0.8576 - val_loss: 0.3747 - val_accuracy: 0.8429
# Epoch 26/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3405 - accuracy: 0.8567 - val_loss: 0.3714 - val_accuracy: 0.8440
# Epoch 27/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3389 - accuracy: 0.8578 - val_loss: 0.3706 - val_accuracy: 0.8451
# Epoch 28/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3377 - accuracy: 0.8574 - val_loss: 0.3692 - val_accuracy: 0.8448
# Epoch 29/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3358 - accuracy: 0.8595 - val_loss: 0.3691 - val_accuracy: 0.8436
# Epoch 30/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3349 - accuracy: 0.8591 - val_loss: 0.3675 - val_accuracy: 0.8474
# Epoch 31/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3341 - accuracy: 0.8567 - val_loss: 0.3661 - val_accuracy: 0.8470
# Epoch 32/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3328 - accuracy: 0.8599 - val_loss: 0.3650 - val_accuracy: 0.8482
# Epoch 33/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3321 - accuracy: 0.8582 - val_loss: 0.3649 - val_accuracy: 0.8459
# Epoch 34/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3319 - accuracy: 0.8580 - val_loss: 0.3659 - val_accuracy: 0.8493
# Epoch 35/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3310 - accuracy: 0.8571 - val_loss: 0.3651 - val_accuracy: 0.8482
# Epoch 36/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3300 - accuracy: 0.8591 - val_loss: 0.3687 - val_accuracy: 0.8470
# Epoch 37/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3300 - accuracy: 0.8576 - val_loss: 0.3650 - val_accuracy: 0.8497
# Epoch 38/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3300 - accuracy: 0.8586 - val_loss: 0.3642 - val_accuracy: 0.8482
# Epoch 39/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3293 - accuracy: 0.8580 - val_loss: 0.3653 - val_accuracy: 0.8482
# Epoch 40/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3290 - accuracy: 0.8602 - val_loss: 0.3639 - val_accuracy: 0.8516
# Epoch 41/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3289 - accuracy: 0.8602 - val_loss: 0.3639 - val_accuracy: 0.8512
# Epoch 42/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3279 - accuracy: 0.8602 - val_loss: 0.3634 - val_accuracy: 0.8501
# Epoch 43/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3278 - accuracy: 0.8591 - val_loss: 0.3625 - val_accuracy: 0.8504
# Epoch 44/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3273 - accuracy: 0.8619 - val_loss: 0.3624 - val_accuracy: 0.8504
# Epoch 45/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3273 - accuracy: 0.8602 - val_loss: 0.3627 - val_accuracy: 0.8542
# Epoch 46/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3272 - accuracy: 0.8615 - val_loss: 0.3633 - val_accuracy: 0.8523
# Epoch 47/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3269 - accuracy: 0.8619 - val_loss: 0.3625 - val_accuracy: 0.8531
# Epoch 48/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3265 - accuracy: 0.8608 - val_loss: 0.3615 - val_accuracy: 0.8535
# Epoch 49/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3258 - accuracy: 0.8599 - val_loss: 0.3621 - val_accuracy: 0.8519
# Epoch 50/50
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3261 - accuracy: 0.8619 - val_loss: 0.3609 - val_accuracy: 0.8527
# 63/63 [==============================] - 0s 991us/step
# [[1515   80]
#  [ 202  203]]
# The accuracy of the model is 0.859
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      1595
#            1       0.72      0.50      0.59       405
#
#     accuracy                           0.86      2000
#    macro avg       0.80      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
